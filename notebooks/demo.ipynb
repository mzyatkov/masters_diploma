# %% [markdown]
# # Demo: synthetic pipeline
#
# Запуск из корня репозитория с активированным venv. См. также `scripts/run_full_pipeline.py`.

# %%
import sys
from pathlib import Path
root = Path.cwd().resolve()
if (root / "src").is_dir():
    sys.path.insert(0, str(root))

from src.pipeline import run_full_pipeline

run_full_pipeline("configs/default.yaml")
